# %%
import pandas as pd

# Define the file paths
TRAIN_FILE_PATH = r"C:\Users\Mayank Meghwal\Desktop\Assignment SHL\data\provided\train_set.csv"
TEST_FILE_PATH = r"C:\Users\Mayank Meghwal\Desktop\Assignment SHL\data\provided\test_set.csv"

try:
    # Load the training data
    train_df = pd.read_csv(TRAIN_FILE_PATH)

    # Load the testing data
    test_df = pd.read_csv(TEST_FILE_PATH)

    print("--- Successfully loaded training data: ---")
    print(train_df.head())
    print(f"\nTotal training queries: {train_df['Query'].nunique()}")

    print("\n--- Successfully loaded testing data: ---")
    print(test_df.head())
    print(f"\nTotal testing queries: {test_df.shape[0]}")

except FileNotFoundError as e:
    print(f"Error: {e}")
    print("Please make sure your files are in the 'data/provided/' directory")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# --- Successfully loaded training data: ---
#                                                Query  \
# 0  I am hiring for Java developers who can also c...
# 1  I am hiring for Java developers who can also c...
# 2  I am hiring for Java developers who can also c...
# 3  I am hiring for Java developers who can also c...
# 4  I am hiring for Java developers who can also c...
#
#                                       Assessment_url
# 0  https://www.shl.com/solutions/products/product...
# 1  https://www.shl.com/solutions/products/product...
# 2  https://www.shl.com/solutions/products/product...
# 3  https://www.shl.com/solutions/products/product...
# 4  https://www.shl.com/products/product-catalog/v...
#
# Total training queries: 10
#
# --- Successfully loaded testing data: ---
#                                                Query
# 0  Looking to hire mid-level professionals who ar...
# 1  Job Description\n\n Join a community that is s...
# ...
